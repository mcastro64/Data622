# %%
import pandas as pd
import numpy as np
import seaborn as sns                       
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
#import file
banks_ori_df = pd.read_csv('data/bank/bank-full.csv', sep=';')
banks_ext_df = pd.read_csv('data/bank-additional/bank-additional-full.csv', sep=';')

# %%
# number of rows and cols
print('\nShape of dataframe')
print('Original DF:', banks_ori_df.shape)
print('Extended DF:', banks_ext_df.shape)
# Out:
# Shape of dataframe
# Original DF: (45211, 17)
# Extended DF: (41188, 21)

# %%
print('\nColumn Types | Original Df:\n')
print(banks_ori_df.head())
print('\nColumn Types | _Extended Df\n')
print(banks_ext_df.head())
# Out:
# Column Types | Original Df:
#
#    age           job  marital  education default  ...  campaign pdays  \
# 0   58    management  married   tertiary      no  ...         1    -1
# 1   44    technician   single  secondary      no  ...         1    -1
# 2   33  entrepreneur  married  secondary      no  ...         1    -1
# 3   47   blue-collar  married    unknown      no  ...         1    -1
# 4   33       unknown   single    unknown      no  ...         1    -1
#
#   previous poutcome   y
# 0        0  unknown  no
# 1        0  unknown  no
# 2        0  unknown  no
# 3        0  unknown  no
# 4        0  unknown  no
#
# [5 rows x 17 columns]
#
# Column Types | _Extended Df
#
#    age        job  marital    education  default  ... cons.price.idx  \
# 0   56  housemaid  married     basic.4y       no  ...         93.994
# 1   57   services  married  high.school  unknown  ...         93.994
# 2   37   services  married  high.school       no  ...         93.994
# 3   40     admin.  married     basic.6y       no  ...         93.994
# 4   56   services  married  high.school       no  ...         93.994
#
#   cons.conf.idx euribor3m nr.employed   y
# 0         -36.4     4.857      5191.0  no
# 1         -36.4     4.857      5191.0  no
# 2         -36.4     4.857      5191.0  no
# 3         -36.4     4.857      5191.0  no
# 4         -36.4     4.857      5191.0  no
#
# [5 rows x 21 columns]

# %%
#check null rows - inverse of non-null values
print('\n# of Null Rows | Origianl Df:')
print(banks_ori_df.isnull().sum())
print('\n# of Null Rows | Extended Df:')
print(banks_ext_df.isnull().sum())
# Out:
# # of Null Rows | Origianl Df:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64
#
# # of Null Rows | Extended Df:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
# Select categorical columns
#banks_ori_df['campaign'] = banks_ori_df['campaign'].astype('category')
ori_categorical_cols = banks_ori_df.select_dtypes(include=['object', 'category']).columns
ori_noncategorical_cols = banks_ori_df.drop(columns=ori_categorical_cols).columns

#banks_ext_df['campaign'] = banks_ext_df['campaign'].astype('category')
ext_categorical_cols = banks_ext_df.select_dtypes(include=['object', 'category']).columns
ext_noncategorical_cols = banks_ext_df.drop(columns=ext_categorical_cols).columns

# %%
# column types
print('\nColumn Types and Non-null Values')
print('__Original DF:__\n', banks_ori_df.info())
print('\n__Extended DF:__\n', banks_ext_df.info())
# Out:
# Column Types and Non-null Values
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB
# __Original DF:__
#  None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41188 entries, 0 to 41187
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             41188 non-null  int64
#  1   job             41188 non-null  object
#  2   marital         41188 non-null  object
#  3   education       41188 non-null  object
#  4   default         41188 non-null  object
#  5   housing         41188 non-null  object
#  6   loan            41188 non-null  object
#  7   contact         41188 non-null  object
#  8   month           41188 non-null  object
#  9   day_of_week     41188 non-null  object
#  10  duration        41188 non-null  int64
#  11  campaign        41188 non-null  int64
#  12  pdays           41188 non-null  int64
#  13  previous        41188 non-null  int64
#  14  poutcome        41188 non-null  object
#  15  emp.var.rate    41188 non-null  float64
#  16  cons.price.idx  41188 non-null  float64
#  17  cons.conf.idx   41188 non-null  float64
#  18  euribor3m       41188 non-null  float64
#  19  nr.employed     41188 non-null  float64
#  20  y               41188 non-null  object
# dtypes: float64(5), int64(5), object(11)
# memory usage: 6.6+ MB
#
# __Extended DF:__
#  None

# %%
# print facetterd barplots for categorical values
# g_ori = sns.catplot(
#     data=banks_ori_df.melt(value_vars=ori_categorical_cols), 
#     kind='count',
#     x='value',
#     col='variable',
#     col_wrap=5, 
#     height=4,
#     aspect=1,
#     sharex=False
# )
# g_ori.figure.subplots_adjust(wspace=0.5, hspace=0.5)
# g_ori.set_xticklabels(rotation=45, ha="right")
#plt.show()

custom_order = ['mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']
banks_ori_df['month'] = pd.Categorical(banks_ori_df['month'], categories=custom_order, ordered=True)

max_cols = 5
max_rows = 2
fig_ori_dist, axes = plt.subplots(ncols=max_cols, nrows=max_rows, figsize=(15, 6))

x_counter = 0
y_counter = 0
for i, col in enumerate(ori_categorical_cols):
    sns.histplot(data=banks_ori_df, x=col, hue='y', ax=axes[y_counter, x_counter], multiple="stack", shrink=0.8)
    axes[y_counter, x_counter].tick_params(axis='x', labelsize=8,  labelrotation=90)
    axes[y_counter, x_counter].get_legend().remove()
    x_counter += 1
    if x_counter == max_cols:
        x_counter = 0
        y_counter += 1
    if i == len(ori_categorical_cols) :
        break

fig_ori_dist.suptitle("Counts for Original Df Categorical Vars", fontsize=14)
plt.tight_layout(pad=1)
plt.show()


#  print value counts
print('\nCategorical Values by Column | Original Df:')
for i, col in enumerate(ori_categorical_cols):
    banks_ori_df[col] = banks_ori_df[col].astype('category')
    val_counts = banks_ori_df[col].value_counts()

    val_percent = banks_ori_df[col].value_counts(normalize=True) * 100

    summary = pd.DataFrame({
        'Count': val_counts,
        'Percentage': val_percent.round(2) 
    })
    
    print(f"\nValues for Original DF column : {val_counts}")
    print(summary)
# Out:
# Categorical Values by Column | Original Df:
#
# Values for Original DF column : job
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: count, dtype: int64
#                Count  Percentage
# job
# blue-collar     9732       21.53
# management      9458       20.92
# technician      7597       16.80
# admin.          5171       11.44
# services        4154        9.19
# retired         2264        5.01
# self-employed   1579        3.49
# entrepreneur    1487        3.29
# unemployed      1303        2.88
# housemaid       1240        2.74
# student          938        2.07
# unknown          288        0.64
#
# Values for Original DF column : marital
# married     27214
# single      12790
# divorced     5207
# Name: count, dtype: int64
#           Count  Percentage
# marital
# married   27214       60.19
# single    12790       28.29
# divorced   5207       11.52
#
# Values for Original DF column : education
# secondary    23202
# tertiary     13301
# primary       6851
# unknown       1857
# Name: count, dtype: int64
#            Count  Percentage
# education
# secondary  23202       51.32
# tertiary   13301       29.42
# primary     6851       15.15
# unknown     1857        4.11
#
# Values for Original DF column : default
# no     44396
# yes      815
# Name: count, dtype: int64
#          Count  Percentage
# default
# no       44396        98.2
# yes        815         1.8
#
# Values for Original DF column : housing
# yes    25130
# no     20081
# Name: count, dtype: int64
#          Count  Percentage
# housing
# yes      25130       55.58
# no       20081       44.42
#
# Values for Original DF column : loan
# no     37967
# yes     7244
# Name: count, dtype: int64
#       Count  Percentage
# loan
# no    37967       83.98
# yes    7244       16.02
#
# Values for Original DF column : contact
# cellular     29285
# unknown      13020
# telephone     2906
# Name: count, dtype: int64
#            Count  Percentage
# contact
# cellular   29285       64.77
# unknown    13020       28.80
# telephone   2906        6.43
#
# Values for Original DF column : month
# may    13766
# jul     6895
# aug     6247
# jun     5341
# nov     3970
# apr     2932
# oct      738
# sep      579
# mar      477
# dec      214
# Name: count, dtype: int64
#        Count  Percentage
# month
# may    13766       33.45
# jul     6895       16.75
# aug     6247       15.18
# jun     5341       12.98
# nov     3970        9.65
# apr     2932        7.12
# oct      738        1.79
# sep      579        1.41
# mar      477        1.16
# dec      214        0.52
#
# Values for Original DF column : poutcome
# unknown    36959
# failure     4901
# other       1840
# success     1511
# Name: count, dtype: int64
#           Count  Percentage
# poutcome
# unknown   36959       81.75
# failure    4901       10.84
# other      1840        4.07
# success    1511        3.34
#
# Values for Original DF column : y
# no     39922
# yes     5289
# Name: count, dtype: int64
#      Count  Percentage
# y
# no   39922        88.3
# yes   5289        11.7

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(8, 3))

sns.histplot(data=banks_ori_df, x="day", hue="y", ax=ax1)
ax1.set_title("Original Df: Days of Month")

sns.histplot(data=banks_ext_df, x="day_of_week", hue="y", ax=ax2)
ax2.set_title("Extended Df: Days of Week")


fig.suptitle("Distributions of Day (of Month) and Day of Week", fontsize=14)
plt.tight_layout()
plt.show()

# %%
# split of engineered columns
ext_noncategorical_cols = ['age', 'duration', 'campaign', 'pdays', 'previous']
ext_engineered_cols = ['emp.var.rate', 'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed']

banks_ext_simplified_df = banks_ext_df.drop(columns=ext_engineered_cols)
banks_ext_simplified_df = banks_ext_simplified_df.drop(columns=['day_of_week'])

custom_order = ['mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']
banks_ext_simplified_df['month'] = pd.Categorical(banks_ext_simplified_df['month'], categories=custom_order, ordered=True)

     
ext_categorical_cols = banks_ori_df.select_dtypes(include=['object', 'category']).columns


max_cols = 5
max_rows = 2
fig_ext_dist, axes = plt.subplots(ncols=max_cols, nrows=max_rows, figsize=(15, 7))

x_counter = 0
y_counter = 0
for i, col in enumerate(ext_categorical_cols):
    sns.histplot(data=banks_ext_simplified_df, x=col, hue='y', ax=axes[y_counter, x_counter], multiple="stack", shrink=0.8)
    axes[y_counter, x_counter].tick_params(axis='x', labelsize=8,  labelrotation=90)
    axes[y_counter, x_counter].get_legend().remove()
    #axes[i].set_title(f'Countplot for {col}')
    x_counter += 1
    if x_counter == max_cols:
        x_counter = 0
        y_counter += 1
    if i == len(ext_categorical_cols) :
        break


fig_ext_dist.suptitle("Counts for Extended Df Categorical Vars", fontsize=14)
plt.tight_layout(pad=1)
plt.show()

# Combine into a single summary table
print('\nCategorical Values by Columns | Original Df:\n')
for i, col in enumerate(ext_categorical_cols):
    banks_ext_df[col] = banks_ext_df[col].astype('category')
    val_counts = banks_ext_df[col].value_counts()

    print(f"\n📊 Full Breakdown for '{col}' by target 'y'")

    # Crosstab: raw counts
    count_table = pd.crosstab(banks_ext_df[col], banks_ext_df['y'])
    count_table['total'] = banks_ext_df[col].value_counts()
    count_table['% no'] = (count_table['no'] / count_table['total'] * 100).round(2)
    count_table['% yes'] = (count_table['yes'] / count_table['total'] * 100).round(2)
    count_table['% total'] = banks_ext_df[col].value_counts(normalize=True) * 100

    # Rename columns for clarity
    count_table = count_table.rename(columns={'n': 'Count (n)', 'y': 'Count (y)'})

    print(count_table)
# Out:
# Categorical Values by Columns | Original Df:
#
#
# 📊 Full Breakdown for 'job' by target 'y'
# y                no   yes  total   % no  % yes    % total
# job
# admin.         9070  1352  10422  87.03  12.97  25.303486
# blue-collar    8616   638   9254  93.11   6.89  22.467709
# entrepreneur   1332   124   1456  91.48   8.52   3.535010
# housemaid       954   106   1060  90.00  10.00   2.573565
# management     2596   328   2924  88.78  11.22   7.099155
# retired        1286   434   1720  74.77  25.23   4.175974
# self-employed  1272   149   1421  89.51  10.49   3.450034
# services       3646   323   3969  91.86   8.14   9.636302
# student         600   275    875  68.57  31.43   2.124405
# technician     6013   730   6743  89.17  10.83  16.371273
# unemployed      870   144   1014  85.80  14.20   2.461882
# unknown         293    37    330  88.79  11.21   0.801204
#
# 📊 Full Breakdown for 'marital' by target 'y'
# y            no   yes  total   % no  % yes    % total
# marital
# divorced   4136   476   4612  89.68  10.32  11.197436
# married   22396  2532  24928  89.84  10.16  60.522482
# single     9948  1620  11568  86.00  14.00  28.085850
# unknown      68    12     80  85.00  15.00   0.194231
#
# 📊 Full Breakdown for 'education' by target 'y'
# y                       no   yes  total   % no  % yes    % total
# education
# basic.4y              3748   428   4176  89.75  10.25  10.138875
# basic.6y              2104   188   2292  91.80   8.20   5.564728
# basic.9y              5572   473   6045  92.18   7.82  14.676605
# high.school           8484  1031   9515  89.16  10.84  23.101389
# illiterate              14     4     18  77.78  22.22   0.043702
# professional.course   4648   595   5243  88.65  11.35  12.729436
# university.degree    10498  1670  12168  86.28  13.72  29.542585
# unknown               1480   251   1731  85.50  14.50   4.202680
#
# 📊 Full Breakdown for 'default' by target 'y'
# y           no   yes  total    % no  % yes    % total
# default
# no       28391  4197  32588   87.12  12.88  79.120132
# unknown   8154   443   8597   94.85   5.15  20.872584
# yes          3     0      3  100.00   0.00   0.007284
#
# 📊 Full Breakdown for 'housing' by target 'y'
# y           no   yes  total   % no  % yes    % total
# housing
# no       16596  2026  18622  89.12  10.88  45.212198
# unknown    883   107    990  89.19  10.81   2.403613
# yes      19069  2507  21576  88.38  11.62  52.384190
#
# 📊 Full Breakdown for 'loan' by target 'y'
# y           no   yes  total   % no  % yes    % total
# loan
# no       30100  3850  33950  88.66  11.34  82.426920
# unknown    883   107    990  89.19  10.81   2.403613
# yes       5565   683   6248  89.07  10.93  15.169467
#
# 📊 Full Breakdown for 'contact' by target 'y'
# y             no   yes  total   % no  % yes    % total
# contact
# cellular   22291  3853  26144  85.26  14.74  63.474798
# telephone  14257   787  15044  94.77   5.23  36.525202
#
# 📊 Full Breakdown for 'month' by target 'y'
# y         no  yes  total   % no  % yes    % total
# month
# apr     2093  539   2632  79.52  20.48   6.390211
# aug     5523  655   6178  89.40  10.60  14.999514
# dec       93   89    182  51.10  48.90   0.441876
# jul     6525  649   7174  90.95   9.05  17.417694
# jun     4759  559   5318  89.49  10.51  12.911528
# mar      270  276    546  49.45  50.55   1.325629
# may    12883  886  13769  93.57   6.43  33.429640
# nov     3685  416   4101  89.86  10.14   9.956784
# oct      403  315    718  56.13  43.87   1.743226
# sep      314  256    570  55.09  44.91   1.383898
#
# 📊 Full Breakdown for 'poutcome' by target 'y'
# y               no   yes  total   % no  % yes    % total
# poutcome
# failure       3647   605   4252  85.77  14.23  10.323395
# nonexistent  32422  3141  35563  91.17   8.83  86.343110
# success        479   894   1373  34.89  65.11   3.333495
#
# 📊 Full Breakdown for 'y' by target 'y'
# y       no   yes  total   % no  % yes    % total
# y
# no   36548     0  36548  100.0    0.0  88.734583
# yes      0  4640   4640    0.0  100.0  11.265417

# %%
# drop days
ori_noncategorical_cols = ['age', 'duration', 'balance', 'campaign', 'pdays', 'previous']
banks_ori_simplified_df = banks_ori_df.drop(columns=['day'])

# %%
#Boxplots 
fig, axes = plt.subplots(ncols=3, nrows=2, figsize=(15, 5))
x_counter = 0
y_counter = 0
for i, col in enumerate(ori_noncategorical_cols):
    sns.boxplot(data=banks_ori_df, x=col, y='y', ax=axes[y_counter, x_counter])
    #axes[i].set_title(f'Countplot for {col}')
    #axes[i].tick_params(axis='x', rotation=45)
    x_counter += 1
    if x_counter == 3:
        x_counter = 0
        y_counter += 1
    if i == len(ori_noncategorical_cols) :
        break

fig.suptitle("Boxplots Original Df Continuous Vars", fontsize=14)
plt.tight_layout()
plt.show()

# df summary
print('\nSummary metrics for numerical fields | Original Df')
print(banks_ori_df.describe())

for i, col in enumerate(ori_noncategorical_cols):
        
    top_values = banks_ori_df.nlargest(5, col)
    
    print(f'\nTop 5 `{col}`', top_values[col])
    Q1 = banks_ori_df[col].quantile(0.25)
    Q3 = banks_ori_df[col].quantile(0.75)
    upper_whisker =  Q3 + 1.5 * (Q3 - Q1)
    
    print(f'\nUpper Whisker: `{col}`', upper_whisker)
    count_above_whisker = (banks_ori_df[col] > upper_whisker).sum()
    print("Count above upper whisker:", count_above_whisker)
# Out:
# Summary metrics for numerical fields | Original Df
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# 75%       -1.000000      0.000000
# max      871.000000    275.000000
#
# Top 5 `age` 33699    95
# 41663    95
# 31233    94
# 44262    93
# 44420    93
# Name: age, dtype: int64
#
# Upper Whisker: `age` 70.5
# Count above upper whisker: 487
#
# Top 5 `duration` 24148    4918
# 9947     3881
# 44602    3785
# 19639    3422
# 2386     3366
# Name: duration, dtype: int64
#
# Upper Whisker: `duration` 643.0
# Count above upper whisker: 3235
#
# Top 5 `balance` 39989    102127
# 26227     98417
# 42558     81204
# 43393     81204
# 41693     71188
# Name: balance, dtype: int64
#
# Upper Whisker: `balance` 3462.0
# Count above upper whisker: 4712
#
# Top 5 `campaign` 4330     63
# 11914    58
# 5073     55
# 4299     51
# 5459     50
# Name: campaign, dtype: int64
#
# Upper Whisker: `campaign` 6.0
# Count above upper whisker: 3064
#
# Top 5 `pdays` 45146    871
# 44829    854
# 44837    850
# 44858    842
# 44785    838
# Name: pdays, dtype: int64
#
# Upper Whisker: `pdays` -1.0
# Count above upper whisker: 8257
#
# Top 5 `previous` 29182    275
# 38326     58
# 44089     55
# 28886     51
# 44822     41
# Name: previous, dtype: int64
#
# Upper Whisker: `previous` 0.0
# Count above upper whisker: 8257

# %%
# Remove extreme outli
df = banks_ori_df[banks_ori_df['previous'] != banks_ori_df['previous'].max()]

sns.boxplot(data=df, x='previous', y='y')
plt.title("Boxplot of Previous After Removing Extreme Outlier")
plt.show()

print(df['previous'].describe())
# Out:
# count    45210.000000
# mean         0.574253
# std          1.907928
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          0.000000
# max         58.000000
# Name: previous, dtype: float64

# %%
#Boxplots for Ext
fig, axes = plt.subplots(ncols=3, nrows=2, figsize=(15, 5))
print(ext_noncategorical_cols)


# recode pdays from 999 to -1 to match original_df
banks_ext_df['pdays'] = banks_ext_df['pdays'].replace(999, -1)

x_counter = 0
y_counter = 0
for i, col in enumerate(ext_noncategorical_cols):
    if x_counter == 2 and y_counter == 0 :
        x_counter = 0
        y_counter = 1
    sns.boxplot(data=banks_ext_df, x=col, y='y', ax=axes[y_counter, x_counter])
    x_counter += 1
    if x_counter == 3:
        x_counter = 0
        y_counter += 1
    if i == len(ext_noncategorical_cols):
        break

fig.suptitle("Boxplots Extended Df Continuous Vars", fontsize=14)
plt.tight_layout()


# df summary

print('\nSummary metrics for numerical fields | Extended Df')
print(banks_ext_df.describe())

for i, col in enumerate(ext_noncategorical_cols):
        
    top_values = banks_ext_df.nlargest(5, col)
    bot_values = banks_ext_df.nsmallest(5, col)
    
    print(f'\nTop 5 `{col}`', top_values[col])
    print(f'\nBottom 5 `{col}`', bot_values[col])
    Q1 = banks_ext_df[col].quantile(0.25)
    Q3 = banks_ext_df[col].quantile(0.75)
    upper_whisker =  Q3 + 1.5 * (Q3 - Q1)
    
    print(f'\nUpper Whisker `{col}`', upper_whisker)
    count_above_whisker = (banks_ext_df[col] > upper_whisker).sum()
    print("Count above upper whisker:", count_above_whisker)

plt.show()
# Out:
# ['age', 'duration', 'campaign', 'pdays', 'previous']
#
# Summary metrics for numerical fields | Extended Df
#                age      duration      campaign         pdays      previous  \
# count  41188.00000  41188.000000  41188.000000  41188.000000  41188.000000
# mean      40.02406    258.285010      2.567593     -0.741988      0.172963
# std       10.42125    259.279249      2.770014      1.510327      0.494901
# min       17.00000      0.000000      1.000000     -1.000000      0.000000
# 25%       32.00000    102.000000      1.000000     -1.000000      0.000000
# 50%       38.00000    180.000000      2.000000     -1.000000      0.000000
# 75%       47.00000    319.000000      3.000000     -1.000000      0.000000
# max       98.00000   4918.000000     56.000000     27.000000      7.000000
#
#        emp.var.rate  cons.price.idx  cons.conf.idx     euribor3m   nr.employed
# count  41188.000000    41188.000000   41188.000000  41188.000000  41188.000000
# mean       0.081886       93.575664     -40.502600      3.621291   5167.035911
# std        1.570960        0.578840       4.628198      1.734447     72.251528
# min       -3.400000       92.201000     -50.800000      0.634000   4963.600000
# 25%       -1.800000       93.075000     -42.700000      1.344000   5099.100000
# 50%        1.100000       93.749000     -41.800000      4.857000   5191.000000
# 75%        1.400000       93.994000     -36.400000      4.961000   5228.100000
# max        1.400000       94.767000     -26.900000      5.045000   5228.100000
#
# Top 5 `age` 38452    98
# 38455    98
# 27826    95
# 38921    94
# 39655    92
# Name: age, dtype: int64
#
# Bottom 5 `age` 37140    17
# 37539    17
# 37558    17
# 37579    17
# 38274    17
# Name: age, dtype: int64
#
# Upper Whisker `age` 69.5
# Count above upper whisker: 469
#
# Top 5 `duration` 24091    4918
# 22192    4199
# 40537    3785
# 13820    3643
# 7727     3631
# Name: duration, dtype: int64
#
# Bottom 5 `duration` 6251     0
# 23031    0
# 28063    0
# 33015    0
# 28239    1
# Name: duration, dtype: int64
#
# Upper Whisker `duration` 644.5
# Count above upper whisker: 2963
#
# Top 5 `campaign` 4107     56
# 13447    43
# 18728    43
# 4168     42
# 5304     42
# Name: campaign, dtype: int64
#
# Bottom 5 `campaign` 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: campaign, dtype: int64
#
# Upper Whisker `campaign` 6.0
# Count above upper whisker: 2406
#
# Top 5 `pdays` 40874    27
# 40243    26
# 40234    25
# 39883    22
# 40489    22
# Name: pdays, dtype: int64
#
# Bottom 5 `pdays` 0   -1
# 1   -1
# 2   -1
# 3   -1
# 4   -1
# Name: pdays, dtype: int64
#
# Upper Whisker `pdays` -1.0
# Count above upper whisker: 1515
#
# Top 5 `previous` 41081    7
# 40395    6
# 40421    6
# 40436    6
# 41090    6
# Name: previous, dtype: int64
#
# Bottom 5 `previous` 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: previous, dtype: int64
#
# Upper Whisker `previous` 0.0
# Count above upper whisker: 5625

# %%
### EXT

# Log transform non-categorical variables

banks_ext_log_df = df
banks_ext_log_df[ext_noncategorical_cols] = banks_ext_log_df[ext_noncategorical_cols].apply(lambda x: np.sign(x) * np.log1p(abs(x)))


fig, axes = plt.subplots(ncols=3, nrows=2, figsize=(15, 5))
x_counter = 0
y_counter = 0

for i, col in enumerate(ext_noncategorical_cols):
    if x_counter == 2 and y_counter == 0 :
        x_counter = 0
        y_counter = 1
    sns.boxplot(data=banks_ext_log_df, x=col, y='y', ax=axes[y_counter, x_counter])

    x_counter += 1
    if x_counter == 3:
        x_counter = 0
        y_counter += 1
    if i == len(ext_noncategorical_cols ) :
        break

fig.suptitle("Boxplots Original Df Continuous Vars after Log transform | Extended DF", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# /var/folders/xn/ctktyxn56wd47vb1d0kw17_w0000gn/T/ipykernel_45770/1860910005.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   banks_ext_log_df[ext_noncategorical_cols] = banks_ext_log_df[ext_noncategorical_cols].apply(lambda x: np.sign(x) * np.log1p(abs(x)))
# /var/folders/xn/ctktyxn56wd47vb1d0kw17_w0000gn/T/ipykernel_45770/1860910005.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   banks_ext_log_df[ext_noncategorical_cols] = banks_ext_log_df[ext_noncategorical_cols].apply(lambda x: np.sign(x) * np.log1p(abs(x)))

# %%
# recode pdays from 999 to -1 to match original_df
banks_ext_simplified_df['pdays'] = banks_ext_simplified_df['pdays'].replace(999, -1)

sns.pairplot(banks_ext_simplified_df, hue='y')

# %%
for i, col in enumerate(ext_noncategorical_cols):
    val_counts = df[col].value_counts()
    
    print(f"\n📊 Full Breakdown for '{col}' by target 'y'")
    
    df = banks_ext_df
    if col == 'age' :
        df = banks_ext_df[(banks_ext_df['age'] > 22) & (banks_ext_df['age'] < 61)]
    # Crosstab: raw counts
    count_table = pd.crosstab(df[col], banks_ext_df['y'])
    count_table['total'] = df[col].value_counts()
    count_table['% no'] = (count_table['no'] / count_table['total'] * 100).round(2)
    count_table['% yes'] = (count_table['yes'] / count_table['total'] * 100).round(2)
    count_table['% total'] = df[col].value_counts(normalize=True) * 100
    
    # Rename columns for clarity
    count_table = count_table.rename(columns={'n': 'Count (n)', 'y': 'Count (y)'})

    print(count_table)
# Out:
# 📊 Full Breakdown for 'age' by target 'y'
# y      no  yes  total   % no  % yes   % total
# age
# 23    178   48    226  78.76  21.24  0.566430
# 24    377   86    463  81.43  18.57  1.160430
# 25    505   93    598  84.45  15.55  1.498784
# 26    576  122    698  82.52  17.48  1.749417
# 27    737  114    851  86.60  13.40  2.132886
# 28    850  151   1001  84.92  15.08  2.508835
# 29   1267  186   1453  87.20  12.80  3.641695
# 30   1512  202   1714  88.21  11.79  4.295847
# 31   1727  220   1947  88.70  11.30  4.879822
# 32   1662  184   1846  90.03   9.97  4.626682
# 33   1623  210   1833  88.54  11.46  4.594100
# 34   1561  184   1745  89.46  10.54  4.373543
# 35   1592  167   1759  90.51   9.49  4.408632
# 36   1626  154   1780  91.35   8.65  4.461265
# 37   1338  137   1475  90.71   9.29  3.696835
# 38   1264  143   1407  89.84  10.16  3.526404
# 39   1318  114   1432  92.04   7.96  3.589062
# 40   1077   84   1161  92.76   7.24  2.909847
# 41   1165  113   1278  91.16   8.84  3.203088
# 42   1051   91   1142  92.03   7.97  2.862227
# 43    967   88   1055  91.66   8.34  2.644177
# 44    934   77   1011  92.38   7.62  2.533898
# 45   1011   92   1103  91.66   8.34  2.764480
# 46    951   79   1030  92.33   7.67  2.581518
# 47    870   58    928  93.75   6.25  2.325873
# 48    882   97    979  90.09   9.91  2.453696
# 49    784   55    839  93.44   6.56  2.102810
# 50    788   87    875  90.06   9.94  2.193037
# 51    682   72    754  90.45   9.55  1.889772
# 52    698   81    779  89.60  10.40  1.952430
# 53    665   68    733  90.72   9.28  1.837139
# 54    620   64    684  90.64   9.36  1.714329
# 55    592   56    648  91.36   8.64  1.624101
# 56    624   80    704  88.64  11.36  1.764455
# 57    584   62    646  90.40   9.60  1.619088
# 58    518   58    576  89.93  10.07  1.443645
# 59    394   69    463  85.10  14.90  1.160430
# 60    225   58    283  79.51  20.49  0.709291
#
# 📊 Full Breakdown for 'duration' by target 'y'
# y         no  yes  total   % no  % yes   % total
# duration
# 0          4    0      4  100.0    0.0  0.009712
# 1          3    0      3  100.0    0.0  0.007284
# 2          1    0      1  100.0    0.0  0.002428
# 3          3    0      3  100.0    0.0  0.007284
# 4         12    0     12  100.0    0.0  0.029135
# ...       ..  ...    ...    ...    ...       ...
# 3631       0    1      1    0.0  100.0  0.002428
# 3643       0    1      1    0.0  100.0  0.002428
# 3785       1    0      1  100.0    0.0  0.002428
# 4199       0    1      1    0.0  100.0  0.002428
# 4918       1    0      1  100.0    0.0  0.002428
#
# [1544 rows x 6 columns]
#
# 📊 Full Breakdown for 'campaign' by target 'y'
# y            no   yes  total    % no  % yes    % total
# campaign
# 1         15342  2300  17642   86.96  13.04  42.832864
# 2          9359  1211  10570   88.54  11.46  25.662814
# 3          4767   574   5341   89.25  10.75  12.967369
# 4          2402   249   2651   90.61   9.39   6.436341
# 5          1479   120   1599   92.50   7.50   3.882199
# 6           904    75    979   92.34   7.66   2.376906
# 7           591    38    629   93.96   6.04   1.527144
# 8           383    17    400   95.75   4.25   0.971157
# 9           266    17    283   93.99   6.01   0.687093
# 10          213    12    225   94.67   5.33   0.546276
# 11          165    12    177   93.22   6.78   0.429737
# 12          122     3    125   97.60   2.40   0.303486
# 13           88     4     92   95.65   4.35   0.223366
# 14           68     1     69   98.55   1.45   0.167525
# 15           49     2     51   96.08   3.92   0.123822
# 16           51     0     51  100.00   0.00   0.123822
# 17           54     4     58   93.10   6.90   0.140818
# 18           33     0     33  100.00   0.00   0.080120
# 19           26     0     26  100.00   0.00   0.063125
# 20           30     0     30  100.00   0.00   0.072837
# 21           24     0     24  100.00   0.00   0.058269
# 22           17     0     17  100.00   0.00   0.041274
# 23           15     1     16   93.75   6.25   0.038846
# 24           15     0     15  100.00   0.00   0.036418
# 25            8     0      8  100.00   0.00   0.019423
# 26            8     0      8  100.00   0.00   0.019423
# 27           11     0     11  100.00   0.00   0.026707
# 28            8     0      8  100.00   0.00   0.019423
# 29           10     0     10  100.00   0.00   0.024279
# 30            7     0      7  100.00   0.00   0.016995
# 31            7     0      7  100.00   0.00   0.016995
# 32            4     0      4  100.00   0.00   0.009712
# 33            4     0      4  100.00   0.00   0.009712
# 34            3     0      3  100.00   0.00   0.007284
# 35            5     0      5  100.00   0.00   0.012139
# 37            1     0      1  100.00   0.00   0.002428
# 39            1     0      1  100.00   0.00   0.002428
# 40            2     0      2  100.00   0.00   0.004856
# 41            1     0      1  100.00   0.00   0.002428
# 42            2     0      2  100.00   0.00   0.004856
# 43            2     0      2  100.00   0.00   0.004856
# 56            1     0      1  100.00   0.00   0.002428
#
# 📊 Full Breakdown for 'pdays' by target 'y'
# y         no   yes  total    % no   % yes    % total
# pdays
# -1     36000  3673  39673   90.74    9.26  96.321744
#  0         5    10     15   33.33   66.67   0.036418
#  1        18     8     26   69.23   30.77   0.063125
#  2        24    37     61   39.34   60.66   0.148101
#  3       141   298    439   32.12   67.88   1.065844
#  4        55    63    118   46.61   53.39   0.286491
#  5        17    29     46   36.96   63.04   0.111683
#  6       123   289    412   29.85   70.15   1.000291
#  7        20    40     60   33.33   66.67   0.145673
#  8         6    12     18   33.33   66.67   0.043702
#  9        29    35     64   45.31   54.69   0.155385
#  10       22    30     52   42.31   57.69   0.126250
#  11       13    15     28   46.43   53.57   0.067981
#  12       32    26     58   55.17   44.83   0.140818
#  13        8    28     36   22.22   77.78   0.087404
#  14        9    11     20   45.00   55.00   0.048558
#  15        8    16     24   33.33   66.67   0.058269
#  16        5     6     11   45.45   54.55   0.026707
#  17        6     2      8   75.00   25.00   0.019423
#  18        3     4      7   42.86   57.14   0.016995
#  19        2     1      3   66.67   33.33   0.007284
#  20        1     0      1  100.00    0.00   0.002428
#  21        0     2      2    0.00  100.00   0.004856
#  22        1     2      3   33.33   66.67   0.007284
#  25        0     1      1    0.00  100.00   0.002428
#  26        0     1      1    0.00  100.00   0.002428
#  27        0     1      1    0.00  100.00   0.002428
#
# 📊 Full Breakdown for 'previous' by target 'y'
# y            no   yes  total    % no  % yes    % total
# previous
# 0         32422  3141  35563   91.17   8.83  86.343110
# 1          3594   967   4561   78.80  21.20  11.073614
# 2           404   350    754   53.58  46.42   1.830630
# 3            88   128    216   40.74  59.26   0.524425
# 4            32    38     70   45.71  54.29   0.169952
# 5             5    13     18   27.78  72.22   0.043702
# 6             2     3      5   40.00  60.00   0.012139
# 7             1     0      1  100.00   0.00   0.002428

# %%
#Correlation heatmap
plt.figure(figsize=(10,5))
c = banks_ext_df[ext_noncategorical_cols].corr()
sns.heatmap(c, cmap="BrBG", annot=True)

print('\n Correlation Heatmap | Extended Df')
print(c)
# Out:
#  Correlation Heatmap | Extended Df
#                age  duration  campaign     pdays  previous
# age       1.000000 -0.000866  0.004594  0.020467  0.024365
# duration -0.000866  1.000000 -0.071699  0.048674  0.020640
# campaign  0.004594 -0.071699  1.000000 -0.044047 -0.079141
# pdays     0.020467  0.048674 -0.044047  1.000000  0.506531
# previous  0.024365  0.020640 -0.079141  0.506531  1.000000

# %%
# make dummy varible for contacted status
banks_ext_simplified_df["was_contacted_before"] = (banks_ext_simplified_df["pdays"] != -1).astype(int)
banks_ext_simplified_df["pdays"] = banks_ext_simplified_df["pdays"].replace(-1, np.nan)

# %%
education_bins = {
    "basic.4y": "primary",
    "basic.6y": "primary",
    "basic.9y": "secondary",
    "high.school": "secondary",
    "university.degree": "tertiary",
    "professional.course": "other",
    "unknown": "other",
    "illiterate": "other"
}

df = banks_ext_df.drop(["day_of_week", "month", "duration","emp.var.rate", "cons.price.idx", "cons.conf.idx", "euribor3m","nr.employed"], axis=1)
df["education"] = df["education"].map(education_bins)
df['pdays'] = df['pdays'].replace(999, -1)
banks_onehot_df = pd.get_dummies(df, drop_first=True)
# Out:
# ['age',
#  'campaign',
#  'pdays',
#  'previous',
#  'job_blue-collar',
#  'job_entrepreneur',
#  'job_housemaid',
#  'job_management',
#  'job_retired',
#  'job_self-employed',
#  'job_services',
#  'job_student',
#  'job_technician',
#  'job_unemployed',
#  'job_unknown',
#  'marital_married',
#  'marital_single',
#  'marital_unknown',
#  'education_primary',
#  'education_secondary',
#  'education_tertiary',
#  'default_unknown',
#  'default_yes',
#  'housing_unknown',
#  'housing_yes',
#  'loan_unknown',
#  'loan_yes',
#  'contact_telephone',
#  'poutcome_nonexistent',
#  'poutcome_success',
#  'y_yes']

# %%
# correlation for all


plt.figure(figsize=(14,10))
c = banks_onehot_df.corr()
sns.heatmap(c, cmap="BrBG", annot=False)

print('\n Correlation Heatmap | Extended Df')
# Out:
#  Correlation Heatmap | Extended Df

# %%
print('marital_married x marital_single', c.loc["marital_married", "marital_single"])
print('pdays x poutcome_success', c.loc["pdays", "poutcome_success"])
print('pdays x previous', c.loc["pdays", "previous"])
print('pdays x poutcome_nonexistent', c.loc["pdays", "poutcome_nonexistent"])
print('previous x poutcome_nonexistent', c.loc["previous", "poutcome_nonexistent"])
print('age x job_retired', c.loc["age", "job_retired"])
print('age x marital_married', c.loc["age", "marital_married"])
print('age x marital_single', c.loc["age", "marital_single"])
print('education_primary x education_secondary', c.loc["education_primary", "education_secondary"])
print('education_primary x education_tertiary', c.loc["education_primary", "education_tertiary"])
print('education_secondary x education_tertiary', c.loc["education_secondary", "education_tertiary"])

for col in c.columns:
    corr_sorted = (
        c[col]
        .drop(col) 
        .reset_index()
        .rename(columns={"index": "variable", col: "corr"})
        .sort_values(by="corr", ascending=False)
    )
    
    print(f"\n=== Correlations with {col} ===")
    print(corr_sorted.to_string(index=False))
# Out:
# === Correlations with age ===
#             variable      corr
#          job_retired  0.440772
#      marital_married  0.271266
#    education_primary  0.208728
#      default_unknown  0.165001
#        job_housemaid  0.085403
#       job_management  0.062040
#          job_unknown  0.047773
#     poutcome_success  0.035626
#     job_entrepreneur  0.031213
#                y_yes  0.030399
#             previous  0.024365
#                pdays  0.020467
#    contact_telephone  0.007021
#             campaign  0.004594
#          default_yes  0.001891
#      marital_unknown  0.001062
#      housing_unknown -0.001092
#         loan_unknown -0.001092
#    job_self-employed -0.001356
#          housing_yes -0.001414
#       job_unemployed -0.004426
#             loan_yes -0.007198
# poutcome_nonexistent -0.016376
#      job_blue-collar -0.024191
#       job_technician -0.064383
#         job_services -0.065731
#   education_tertiary -0.071138
#  education_secondary -0.120596
#          job_student -0.199749
#       marital_single -0.411703
#
# === Correlations with campaign ===
#             variable      corr
# poutcome_nonexistent  0.087645
#    contact_telephone  0.077368
#      default_unknown  0.033007
#      marital_unknown  0.009873
#    job_self-employed  0.006361
#             loan_yes  0.005294
#                  age  0.004594
#        job_housemaid  0.004226
#    education_primary  0.002694
#          job_unknown  0.002625
#         job_services  0.002383
#      marital_married  0.002332
#       job_technician  0.001557
#       job_unemployed -0.000200
#      housing_unknown -0.000396
#         loan_unknown -0.000396
#   education_tertiary -0.000950
#      job_blue-collar -0.001775
#     job_entrepreneur -0.002203
#  education_secondary -0.003683
#          default_yes -0.003803
#          job_retired -0.006847
#       marital_single -0.007624
#       job_management -0.009135
#          housing_yes -0.010800
#          job_student -0.024657
#                pdays -0.044047
#     poutcome_success -0.050893
#                y_yes -0.066357
#             previous -0.079141
#
# === Correlations with pdays ===
#             variable      corr
#     poutcome_success  0.778275
#             previous  0.506531
#                y_yes  0.279025
#          job_student  0.093561
#          job_retired  0.058360
#       marital_single  0.040681
#   education_tertiary  0.022005
#                  age  0.020467
#       job_unemployed  0.016948
#      marital_unknown  0.009989
#          housing_yes  0.005347
#          job_unknown  0.004482
#       job_technician  0.000314
#        job_housemaid  0.000051
#          default_yes -0.001458
#         loan_unknown -0.001830
#      housing_unknown -0.001830
#             loan_yes -0.002467
#       job_management -0.003157
#    job_self-employed -0.014677
#     job_entrepreneur -0.016946
#    education_primary -0.018240
#  education_secondary -0.024028
#         job_services -0.029311
#      marital_married -0.031366
#             campaign -0.044047
#      job_blue-collar -0.056220
#      default_unknown -0.070494
#    contact_telephone -0.102380
# poutcome_nonexistent -0.429549
#
# === Correlations with previous ===
#             variable      corr
#     poutcome_success  0.524045
#                pdays  0.506531
#                y_yes  0.230181
#          job_student  0.104671
#          job_retired  0.065113
#       marital_single  0.048485
#   education_tertiary  0.025419
#                  age  0.024365
#          housing_yes  0.020446
#      marital_unknown  0.009095
#       job_unemployed  0.008426
#       job_management  0.006735
#         loan_unknown  0.003769
#      housing_unknown  0.003769
#          default_yes  0.002766
#             loan_yes -0.002143
#          job_unknown -0.003345
#  education_secondary -0.006810
#    job_self-employed -0.011231
#        job_housemaid -0.011569
#         job_services -0.011885
#     job_entrepreneur -0.013239
#       job_technician -0.017142
#    education_primary -0.028144
#      marital_married -0.043420
#      job_blue-collar -0.054845
#             campaign -0.079141
#      default_unknown -0.102604
#    contact_telephone -0.212848
# poutcome_nonexistent -0.878776
#
# === Correlations with job_blue-collar ===
#             variable      corr
#    education_primary  0.366260
#      default_unknown  0.176698
#      marital_married  0.129272
#  education_secondary  0.120585
#    contact_telephone  0.094712
# poutcome_nonexistent  0.043843
#         loan_unknown  0.006673
#      housing_unknown  0.006673
#             campaign -0.001775
#          default_yes -0.004594
#      marital_unknown -0.005251
#             loan_yes -0.006127
#          housing_yes -0.016031
#                  age -0.024191
#          job_unknown -0.048379
#             previous -0.054845
#                pdays -0.056220
#     poutcome_success -0.061403
#                y_yes -0.074423
#          job_student -0.079308
#       job_unemployed -0.085523
#        job_housemaid -0.087492
#       marital_single -0.100192
#    job_self-employed -0.101759
#     job_entrepreneur -0.103050
#          job_retired -0.112378
#       job_management -0.148810
#         job_services -0.175791
#       job_technician -0.238178
#   education_tertiary -0.336592
#
# === Correlations with job_entrepreneur ===
#             variable      corr
#   education_tertiary  0.051832
#      marital_married  0.051050
#                  age  0.031213
#    contact_telephone  0.018894
# poutcome_nonexistent  0.007598
#          housing_yes  0.004287
#         loan_unknown  0.000861
#      housing_unknown  0.000861
#      marital_unknown  0.000514
#      default_unknown -0.000940
#          default_yes -0.001634
#             campaign -0.002203
#             loan_yes -0.005449
#    education_primary -0.007460
#             previous -0.013239
#                y_yes -0.016644
#                pdays -0.016946
#          job_unknown -0.017204
#     poutcome_success -0.017238
#          job_student -0.028203
#  education_secondary -0.028758
#       job_unemployed -0.030413
#        job_housemaid -0.031113
#    job_self-employed -0.036186
#          job_retired -0.039962
#       job_management -0.052918
#       marital_single -0.060245
#         job_services -0.062513
#       job_technician -0.084698
#      job_blue-collar -0.103050
#
# === Correlations with job_housemaid ===
#             variable      corr
#    education_primary  0.162055
#                  age  0.085403
#      marital_married  0.042492
#      default_unknown  0.036880
# poutcome_nonexistent  0.014629
#    contact_telephone  0.010455
#             campaign  0.004226
#         loan_unknown  0.003526
#      housing_unknown  0.003526
#      marital_unknown  0.003278
#     poutcome_success  0.002276
#                pdays  0.000051
#          default_yes -0.001387
#             loan_yes -0.002905
#          housing_yes -0.004689
#                y_yes -0.006505
#             previous -0.011569
#          job_unknown -0.014607
#          job_student -0.023945
#       job_unemployed -0.025821
#    job_self-employed -0.030723
#     job_entrepreneur -0.031113
#          job_retired -0.033929
#  education_secondary -0.041886
#       job_management -0.044929
#         job_services -0.053075
#   education_tertiary -0.058528
#       marital_single -0.060971
#       job_technician -0.071911
#      job_blue-collar -0.087492
#
# === Correlations with job_management ===
#             variable      corr
#   education_tertiary  0.248491
#                  age  0.062040
#      marital_married  0.061761
#             previous  0.006735
#         loan_unknown  0.000443
#      housing_unknown  0.000443
#                y_yes -0.000419
#             loan_yes -0.001201
#     poutcome_success -0.001302
#          default_yes -0.002359
#                pdays -0.003157
#      marital_unknown -0.005753
# poutcome_nonexistent -0.007343
#          housing_yes -0.007896
#    contact_telephone -0.009031
#             campaign -0.009135
#          job_unknown -0.024843
#      default_unknown -0.035433
#          job_student -0.040726
#       job_unemployed -0.043918
#        job_housemaid -0.044929
#    job_self-employed -0.052255
#     job_entrepreneur -0.052918
#          job_retired -0.057708
#       marital_single -0.067364
#    education_primary -0.071242
#         job_services -0.090272
#       job_technician -0.122309
#  education_secondary -0.124920
#      job_blue-collar -0.148810
#
# === Correlations with job_retired ===
#             variable      corr
#                  age  0.440772
#    education_primary  0.134068
#                y_yes  0.092221
#     poutcome_success  0.068061
#             previous  0.065113
#                pdays  0.058360
#      marital_married  0.057858
#      default_unknown  0.010152
#      marital_unknown  0.004574
#         loan_unknown  0.002106
#      housing_unknown  0.002106
#          default_yes -0.001782
#          housing_yes -0.002189
#             campaign -0.006847
#             loan_yes -0.007076
#          job_unknown -0.018761
#          job_student -0.030756
#       job_unemployed -0.033166
#        job_housemaid -0.033929
#    contact_telephone -0.035096
#    job_self-employed -0.039462
#     job_entrepreneur -0.039962
# poutcome_nonexistent -0.054113
#  education_secondary -0.057272
#       job_management -0.057708
#   education_tertiary -0.059359
#         job_services -0.068171
#       job_technician -0.092365
#       marital_single -0.105345
#      job_blue-collar -0.112378
#
# === Correlations with job_self-employed ===
#             variable      corr
#   education_tertiary  0.100652
#      marital_married  0.011968
# poutcome_nonexistent  0.007385
#      marital_unknown  0.006768
#             campaign  0.006361
#         loan_unknown  0.005076
#      housing_unknown  0.005076
#    contact_telephone  0.002480
#          housing_yes -0.001166
#                  age -0.001356
#          default_yes -0.001613
#                y_yes -0.004663
#      default_unknown -0.004779
#       marital_single -0.005950
#             loan_yes -0.007624
#             previous -0.011231
#     poutcome_success -0.012871
#                pdays -0.014677
#          job_unknown -0.016988
#          job_student -0.027849
#       job_unemployed -0.030032
#        job_housemaid -0.030723
#     job_entrepreneur -0.036186
#    education_primary -0.038445
#          job_retired -0.039462
#       job_management -0.052255
#  education_secondary -0.054553
#         job_services -0.061730
#       job_technician -0.083637
#      job_blue-collar -0.101759
#
# === Correlations with job_services ===
#             variable      corr
#  education_secondary  0.266532
#    contact_telephone  0.035596
#      default_unknown  0.017728
# poutcome_nonexistent  0.005760
#       marital_single  0.004078
#      housing_unknown  0.003009
#         loan_unknown  0.003009
#             campaign  0.002383
#             loan_yes -0.000247
#          default_yes -0.002787
#      marital_unknown -0.003194
#          housing_yes -0.004799
#             previous -0.011885
#      marital_married -0.018202
#     poutcome_success -0.028558
#                pdays -0.029311
#          job_unknown -0.029348
#                y_yes -0.032301
#          job_student -0.048110
#       job_unemployed -0.051881
#        job_housemaid -0.053075
#    education_primary -0.059989
#    job_self-employed -0.061730
#     job_entrepreneur -0.062513
#                  age -0.065731
#          job_retired -0.068171
#       job_management -0.090272
#       job_technician -0.144485
#      job_blue-collar -0.175791
#   education_tertiary -0.180257
#
# === Correlations with job_student ===
#             variable      corr
#       marital_single  0.216639
#             previous  0.104671
#                y_yes  0.093955
#                pdays  0.093561
#     poutcome_success  0.083321
#  education_secondary  0.043564
#             loan_yes  0.004350
#          housing_yes  0.004261
#         loan_unknown  0.002164
#      housing_unknown  0.002164
#          default_yes -0.001257
#      marital_unknown -0.002675
#          job_unknown -0.013240
#       job_unemployed -0.023406
#        job_housemaid -0.023945
#             campaign -0.024657
#    job_self-employed -0.027849
#     job_entrepreneur -0.028203
#          job_retired -0.030756
#      default_unknown -0.032579
#   education_tertiary -0.032660
#    contact_telephone -0.040422
#       job_management -0.040726
#    education_primary -0.045540
#         job_services -0.048110
#       job_technician -0.065185
# poutcome_nonexistent -0.079189
#      job_blue-collar -0.079308
#      marital_married -0.168294
#                  age -0.199749
#
# === Correlations with job_technician ===
#             variable      corr
#       marital_single  0.057404
# poutcome_nonexistent  0.017557
#          default_yes  0.011601
#          housing_yes  0.011001
#             campaign  0.001557
#                pdays  0.000314
#      marital_unknown -0.001635
#     poutcome_success -0.005036
#                y_yes -0.006149
#             loan_yes -0.006197
#      housing_unknown -0.006459
#         loan_unknown -0.006459
#             previous -0.017142
#   education_tertiary -0.026327
#          job_unknown -0.039763
#    contact_telephone -0.048635
#      marital_married -0.055176
#                  age -0.064383
#          job_student -0.065185
#      default_unknown -0.069659
#       job_unemployed -0.070293
#        job_housemaid -0.071911
#    job_self-employed -0.083637
#     job_entrepreneur -0.084698
#          job_retired -0.092365
#       job_management -0.122309
#         job_services -0.144485
#    education_primary -0.164817
#  education_secondary -0.174636
#      job_blue-collar -0.238178
#
# === Correlations with job_unemployed ===
#             variable      corr
#     poutcome_success  0.024612
#  education_secondary  0.020014
#          default_yes  0.017003
#                pdays  0.016948
#                y_yes  0.014752
#      marital_unknown  0.010784
#      default_unknown  0.009774
#             previous  0.008426
#          housing_yes  0.008101
#    contact_telephone  0.007691
#      marital_married  0.006508
#         loan_unknown  0.002688
#      housing_unknown  0.002688
#             campaign -0.000200
#             loan_yes -0.002105
#                  age -0.004426
#    education_primary -0.005699
# poutcome_nonexistent -0.007993
#       marital_single -0.011780
#   education_tertiary -0.012899
#          job_unknown -0.014278
#          job_student -0.023406
#        job_housemaid -0.025821
#    job_self-employed -0.030032
#     job_entrepreneur -0.030413
#          job_retired -0.033166
#       job_management -0.043918
#         job_services -0.051881
#       job_technician -0.070293
#      job_blue-collar -0.085523
#
# === Correlations with job_unknown ===
#             variable      corr
#      default_unknown  0.055701
#      marital_unknown  0.051704
#                  age  0.047773
#    contact_telephone  0.023454
#      marital_married  0.019097
#    education_primary  0.016601
#     poutcome_success  0.012136
# poutcome_nonexistent  0.006398
#             loan_yes  0.005269
#                pdays  0.004482
#             campaign  0.002625
#                y_yes -0.000151
#          housing_yes -0.000473
#          default_yes -0.000767
#             previous -0.003345
#      housing_unknown -0.005213
#         loan_unknown -0.005213
#       marital_single -0.011322
#          job_student -0.013240
#       job_unemployed -0.014278
#        job_housemaid -0.014607
#    job_self-employed -0.016988
#     job_entrepreneur -0.017204
#          job_retired -0.018761
#       job_management -0.024843
#         job_services -0.029348
#   education_tertiary -0.031333
#  education_secondary -0.031831
#       job_technician -0.039763
#      job_blue-collar -0.048379
#
# === Correlations with marital_married ===
#             variable      corr
#                  age  0.271266
#    education_primary  0.147496
#      default_unknown  0.130395
#      job_blue-collar  0.129272
#    contact_telephone  0.063648
#       job_management  0.061761
#          job_retired  0.057858
#     job_entrepreneur  0.051050
# poutcome_nonexistent  0.043016
#        job_housemaid  0.042492
#          job_unknown  0.019097
#    job_self-employed  0.011968
#          default_yes  0.006893
#       job_unemployed  0.006508
#             campaign  0.002332
#             loan_yes -0.001169
#         loan_unknown -0.003623
#      housing_unknown -0.003623
#  education_secondary -0.010583
#          housing_yes -0.010674
#         job_services -0.018202
#     poutcome_success -0.029876
#                pdays -0.031366
#                y_yes -0.043398
#             previous -0.043420
#      marital_unknown -0.054622
#       job_technician -0.055176
#   education_tertiary -0.105645
#          job_student -0.168294
#       marital_single -0.773785
#
# === Correlations with marital_single ===
#             variable      corr
#          job_student  0.216639
#   education_tertiary  0.117051
#       job_technician  0.057404
#                y_yes  0.054133
#             previous  0.048485
#                pdays  0.040681
#     poutcome_success  0.039238
#          housing_yes  0.014191
#  education_secondary  0.010679
#             loan_yes  0.004999
#         job_services  0.004078
#         loan_unknown  0.000688
#      housing_unknown  0.000688
#          default_yes -0.005334
#    job_self-employed -0.005950
#             campaign -0.007624
#          job_unknown -0.011322
#       job_unemployed -0.011780
#      marital_unknown -0.027569
# poutcome_nonexistent -0.045493
#     job_entrepreneur -0.060245
#        job_housemaid -0.060971
#       job_management -0.067364
#    contact_telephone -0.071159
#      job_blue-collar -0.100192
#          job_retired -0.105345
#      default_unknown -0.123565
#    education_primary -0.152431
#                  age -0.411703
#      marital_married -0.773785
#
# === Correlations with marital_unknown ===
#             variable      corr
#          job_unknown  0.051704
#       job_unemployed  0.010784
#                pdays  0.009989
#             campaign  0.009873
#             previous  0.009095
#   education_tertiary  0.008903
#     poutcome_success  0.007167
#    job_self-employed  0.006768
#                y_yes  0.005211
#          job_retired  0.004574
#        job_housemaid  0.003278
#                  age  0.001062
#     job_entrepreneur  0.000514
#             loan_yes -0.000208
#          default_yes -0.000377
#    education_primary -0.000853
#       job_technician -0.001635
#    contact_telephone -0.002543
#          job_student -0.002675
#         job_services -0.003194
#      housing_unknown -0.003323
#         loan_unknown -0.003323
#      job_blue-collar -0.005251
#       job_management -0.005753
#          housing_yes -0.007627
#      default_unknown -0.007732
#  education_secondary -0.009352
# poutcome_nonexistent -0.011360
#       marital_single -0.027569
#      marital_married -0.054622
#
# === Correlations with education_primary ===
#             variable      corr
#      job_blue-collar  0.366260
#                  age  0.208728
#      default_unknown  0.197034
#        job_housemaid  0.162055
#      marital_married  0.147496
#          job_retired  0.134068
#    contact_telephone  0.070479
# poutcome_nonexistent  0.028241
#          job_unknown  0.016601
#         loan_unknown  0.009382
#      housing_unknown  0.009382
#             campaign  0.002694
#      marital_unknown -0.000853
#          default_yes -0.003684
#             loan_yes -0.005053
#       job_unemployed -0.005699
#     job_entrepreneur -0.007460
#          housing_yes -0.016329
#                pdays -0.018240
#     poutcome_success -0.018442
#                y_yes -0.023775
#             previous -0.028144
#    job_self-employed -0.038445
#          job_student -0.045540
#         job_services -0.059989
#       job_management -0.071242
#       marital_single -0.152431
#       job_technician -0.164817
#   education_tertiary -0.279483
#  education_secondary -0.336312
#
# === Correlations with education_secondary ===
#             variable      corr
#         job_services  0.266532
#      job_blue-collar  0.120585
#    contact_telephone  0.051655
#          job_student  0.043564
#       job_unemployed  0.020014
#       marital_single  0.010679
#          default_yes -0.000782
#      housing_unknown -0.000982
#         loan_unknown -0.000982
#      default_unknown -0.001328
#             campaign -0.003683
# poutcome_nonexistent -0.004227
#             loan_yes -0.004798
#             previous -0.006810
#          housing_yes -0.006816
#      marital_unknown -0.009352
#      marital_married -0.010583
#                pdays -0.024028
#     job_entrepreneur -0.028758
#     poutcome_success -0.031716
#          job_unknown -0.031831
#                y_yes -0.039422
#        job_housemaid -0.041886
#    job_self-employed -0.054553
#          job_retired -0.057272
#                  age -0.120596
#       job_management -0.124920
#       job_technician -0.174636
#    education_primary -0.336312
#   education_tertiary -0.504555
#
# === Correlations with education_tertiary ===
#             variable      corr
#       job_management  0.248491
#       marital_single  0.117051
#    job_self-employed  0.100652
#     job_entrepreneur  0.051832
#                y_yes  0.050364
#     poutcome_success  0.037762
#             previous  0.025419
#                pdays  0.022005
#          housing_yes  0.013840
#             loan_yes  0.012488
#      marital_unknown  0.008903
#             campaign -0.000950
#         loan_unknown -0.005376
#      housing_unknown -0.005376
#          default_yes -0.005527
#       job_unemployed -0.012899
# poutcome_nonexistent -0.017547
#       job_technician -0.026327
#          job_unknown -0.031333
#          job_student -0.032660
#        job_housemaid -0.058528
#          job_retired -0.059359
#                  age -0.071138
#    contact_telephone -0.103159
#      marital_married -0.105645
#      default_unknown -0.142701
#         job_services -0.180257
#    education_primary -0.279483
#      job_blue-collar -0.336592
#  education_secondary -0.504555
#
# === Correlations with default_unknown ===
#             variable      corr
#    education_primary  0.197034
#      job_blue-collar  0.176698
#                  age  0.165001
#    contact_telephone  0.135604
#      marital_married  0.130395
# poutcome_nonexistent  0.104226
#          job_unknown  0.055701
#        job_housemaid  0.036880
#             campaign  0.033007
#         job_services  0.017728
#          job_retired  0.010152
#       job_unemployed  0.009774
#         loan_unknown  0.007942
#      housing_unknown  0.007942
#     job_entrepreneur -0.000940
#  education_secondary -0.001328
#          default_yes -0.004383
#    job_self-employed -0.004779
#             loan_yes -0.005349
#      marital_unknown -0.007732
#          housing_yes -0.016683
#          job_student -0.032579
#       job_management -0.035433
#       job_technician -0.069659
#                pdays -0.070494
#     poutcome_success -0.075740
#                y_yes -0.099293
#             previous -0.102604
#       marital_single -0.123565
#   education_tertiary -0.142701
#
# === Correlations with default_yes ===
#             variable      corr
#       job_unemployed  0.017003
#       job_technician  0.011601
#      marital_married  0.006893
#             previous  0.002766
#                  age  0.001891
#      marital_unknown -0.000377
#          job_unknown -0.000767
#  education_secondary -0.000782
#          job_student -0.001257
#         loan_unknown -0.001339
#      housing_unknown -0.001339
#        job_housemaid -0.001387
#                pdays -0.001458
#     poutcome_success -0.001585
#    job_self-employed -0.001613
#     job_entrepreneur -0.001634
#          job_retired -0.001782
#       job_management -0.002359
#         job_services -0.002787
#                y_yes -0.003041
#          housing_yes -0.003256
#             loan_yes -0.003609
#    education_primary -0.003684
#             campaign -0.003803
#      default_unknown -0.004383
#      job_blue-collar -0.004594
# poutcome_nonexistent -0.004890
#       marital_single -0.005334
#   education_tertiary -0.005527
#    contact_telephone -0.006474
#
# === Correlations with housing_unknown ===
#             variable      corr
#         loan_unknown  1.000000
#    contact_telephone  0.022189
#    education_primary  0.009382
#      default_unknown  0.007942
#      job_blue-collar  0.006673
#    job_self-employed  0.005076
#             previous  0.003769
#        job_housemaid  0.003526
#         job_services  0.003009
#       job_unemployed  0.002688
#          job_student  0.002164
#          job_retired  0.002106
#     job_entrepreneur  0.000861
#       marital_single  0.000688
#       job_management  0.000443
#             campaign -0.000396
#  education_secondary -0.000982
#                  age -0.001092
#          default_yes -0.001339
# poutcome_nonexistent -0.001753
#                pdays -0.001830
#                y_yes -0.002270
#      marital_unknown -0.003323
#      marital_married -0.003623
#     poutcome_success -0.004417
#          job_unknown -0.005213
#   education_tertiary -0.005376
#       job_technician -0.006459
#             loan_yes -0.066363
#          housing_yes -0.164604
#
# === Correlations with housing_yes ===
#             variable      corr
#             loan_yes  0.056651
#             previous  0.020446
#       marital_single  0.014191
#   education_tertiary  0.013840
#     poutcome_success  0.012664
#                y_yes  0.011743
#       job_technician  0.011001
#       job_unemployed  0.008101
#                pdays  0.005347
#     job_entrepreneur  0.004287
#          job_student  0.004261
#          job_unknown -0.000473
#    job_self-employed -0.001166
#                  age -0.001414
#          job_retired -0.002189
#          default_yes -0.003256
#        job_housemaid -0.004689
#         job_services -0.004799
#  education_secondary -0.006816
#      marital_unknown -0.007627
#       job_management -0.007896
#      marital_married -0.010674
#             campaign -0.010800
#      job_blue-collar -0.016031
#    education_primary -0.016329
#      default_unknown -0.016683
# poutcome_nonexistent -0.024546
#    contact_telephone -0.084472
#      housing_unknown -0.164604
#         loan_unknown -0.164604
#
# === Correlations with loan_unknown ===
#             variable      corr
#      housing_unknown  1.000000
#    contact_telephone  0.022189
#    education_primary  0.009382
#      default_unknown  0.007942
#      job_blue-collar  0.006673
#    job_self-employed  0.005076
#             previous  0.003769
#        job_housemaid  0.003526
#         job_services  0.003009
#       job_unemployed  0.002688
#          job_student  0.002164
#          job_retired  0.002106
#     job_entrepreneur  0.000861
#       marital_single  0.000688
#       job_management  0.000443
#             campaign -0.000396
#  education_secondary -0.000982
#                  age -0.001092
#          default_yes -0.001339
# poutcome_nonexistent -0.001753
#                pdays -0.001830
#                y_yes -0.002270
#      marital_unknown -0.003323
#      marital_married -0.003623
#     poutcome_success -0.004417
#          job_unknown -0.005213
#   education_tertiary -0.005376
#       job_technician -0.006459
#             loan_yes -0.066363
#          housing_yes -0.164604
#
# === Correlations with loan_yes ===
#             variable      corr
#          housing_yes  0.056651
#   education_tertiary  0.012488
#             campaign  0.005294
#          job_unknown  0.005269
#       marital_single  0.004999
#          job_student  0.004350
# poutcome_nonexistent  0.000253
#      marital_unknown -0.000208
#         job_services -0.000247
#     poutcome_success -0.000481
#      marital_married -0.001169
#       job_management -0.001201
#       job_unemployed -0.002105
#             previous -0.002143
#                pdays -0.002467
#        job_housemaid -0.002905
#          default_yes -0.003609
#                y_yes -0.004466
#  education_secondary -0.004798
#    education_primary -0.005053
#      default_unknown -0.005349
#     job_entrepreneur -0.005449
#      job_blue-collar -0.006127
#       job_technician -0.006197
#          job_retired -0.007076
#                  age -0.007198
#    job_self-employed -0.007624
#    contact_telephone -0.013367
#      housing_unknown -0.066363
#         loan_unknown -0.066363
#
# === Correlations with contact_telephone ===
#             variable      corr
# poutcome_nonexistent  0.242512
#      default_unknown  0.135604
#      job_blue-collar  0.094712
#             campaign  0.077368
#    education_primary  0.070479
#      marital_married  0.063648
#  education_secondary  0.051655
#         job_services  0.035596
#          job_unknown  0.023454
#         loan_unknown  0.022189
#      housing_unknown  0.022189
#     job_entrepreneur  0.018894
#        job_housemaid  0.010455
#       job_unemployed  0.007691
#                  age  0.007021
#    job_self-employed  0.002480
#      marital_unknown -0.002543
#          default_yes -0.006474
#       job_management -0.009031
#             loan_yes -0.013367
#          job_retired -0.035096
#          job_student -0.040422
#       job_technician -0.048635
#       marital_single -0.071159
#          housing_yes -0.084472
#                pdays -0.102380
#   education_tertiary -0.103159
#     poutcome_success -0.111934
#                y_yes -0.144773
#             previous -0.212848
#
# === Correlations with poutcome_nonexistent ===
#            variable      corr
#   contact_telephone  0.242512
#     default_unknown  0.104226
#            campaign  0.087645
#     job_blue-collar  0.043843
#     marital_married  0.043016
#   education_primary  0.028241
#      job_technician  0.017557
#       job_housemaid  0.014629
#    job_entrepreneur  0.007598
#   job_self-employed  0.007385
#         job_unknown  0.006398
#        job_services  0.005760
#            loan_yes  0.000253
#     housing_unknown -0.001753
#        loan_unknown -0.001753
# education_secondary -0.004227
#         default_yes -0.004890
#      job_management -0.007343
#      job_unemployed -0.007993
#     marital_unknown -0.011360
#                 age -0.016376
#  education_tertiary -0.017547
#         housing_yes -0.024546
#      marital_single -0.045493
#         job_retired -0.054113
#         job_student -0.079189
#               y_yes -0.193507
#               pdays -0.429549
#    poutcome_success -0.466928
#            previous -0.878776
#
# === Correlations with poutcome_success ===
#             variable      corr
#                pdays  0.778275
#             previous  0.524045
#                y_yes  0.316269
#          job_student  0.083321
#          job_retired  0.068061
#       marital_single  0.039238
#   education_tertiary  0.037762
#                  age  0.035626
#       job_unemployed  0.024612
#          housing_yes  0.012664
#          job_unknown  0.012136
#      marital_unknown  0.007167
#        job_housemaid  0.002276
#             loan_yes -0.000481
#       job_management -0.001302
#          default_yes -0.001585
#      housing_unknown -0.004417
#         loan_unknown -0.004417
#       job_technician -0.005036
#    job_self-employed -0.012871
#     job_entrepreneur -0.017238
#    education_primary -0.018442
#         job_services -0.028558
#      marital_married -0.029876
#  education_secondary -0.031716
#             campaign -0.050893
#      job_blue-collar -0.061403
#      default_unknown -0.075740
#    contact_telephone -0.111934
# poutcome_nonexistent -0.466928
#
# === Correlations with y_yes ===
#             variable      corr
#     poutcome_success  0.316269
#                pdays  0.279025
#             previous  0.230181
#          job_student  0.093955
#          job_retired  0.092221
#       marital_single  0.054133
#   education_tertiary  0.050364
#                  age  0.030399
#       job_unemployed  0.014752
#          housing_yes  0.011743
#      marital_unknown  0.005211
#          job_unknown -0.000151
#       job_management -0.000419
#      housing_unknown -0.002270
#         loan_unknown -0.002270
#          default_yes -0.003041
#             loan_yes -0.004466
#    job_self-employed -0.004663
#       job_technician -0.006149
#        job_housemaid -0.006505
#     job_entrepreneur -0.016644
#    education_primary -0.023775
#         job_services -0.032301
#  education_secondary -0.039422
#      marital_married -0.043398
#             campaign -0.066357
#      job_blue-collar -0.074423
#      default_unknown -0.099293
#    contact_telephone -0.144773
# poutcome_nonexistent -0.193507

# %%
bool_cols = banks_onehot_df.select_dtypes(include="bool").columns
banks_onehot_df[bool_cols] = banks_onehot_df[bool_cols].astype(int)
numeric_cols = banks_onehot_df.select_dtypes(include=["int64", "float64"]).columns
X = banks_onehot_df[numeric_cols]

# Calculate VIF for each feature
vif_data = pd.DataFrame()
vif_data["feature"] = X.columns
vif_data["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print(vif_data)
# Out:
# /Users/marcocastro/Documents/SPS/Data622/Assignment1/my_project_env/lib/python3.13/site-packages/statsmodels/stats/outliers_influence.py:197: RuntimeWarning: divide by zero encountered in scalar divide
#   vif = 1. / (1. - r_squared_i)
#                  feature        VIF
# 0                    age  17.397092
# 1               campaign   1.873211
# 2                  pdays   3.214631
# 3               previous   3.802058
# 4        job_blue-collar   2.520763
# 5       job_entrepreneur   1.153179
# 6          job_housemaid   1.189847
# 7         job_management   1.320373
# 8            job_retired   1.499877
# 9      job_self-employed   1.137965
# 10          job_services   1.530550
# 11           job_student   1.166967
# 12        job_technician   1.849639
# 13        job_unemployed   1.109210
# 14           job_unknown   1.059802
# 15       marital_married   5.834277
# 16        marital_single   3.299210
# 17       marital_unknown   1.018565
# 18     education_primary   2.459073
# 19   education_secondary   3.625672
# 20    education_tertiary   3.144245
# 21       default_unknown   1.411228
# 22           default_yes   1.000781
# 23       housing_unknown        inf
# 24           housing_yes   2.147585
# 25          loan_unknown        inf
# 26              loan_yes   1.185073
# 27     contact_telephone   1.752232
# 28  poutcome_nonexistent  20.015393
# 29      poutcome_success   2.833491
# 30                 y_yes   1.300391

# %%
print('marital_married x marital_single', c.loc["marital_married", "marital_single"])
print('pdays x poutcome_success', c.loc["pdays", "poutcome_success"])
print('pdays x previous', c.loc["pdays", "previous"])
print('pdays x poutcome_nonexistent', c.loc["pdays", "poutcome_nonexistent"])
print('previous x poutcome_nonexistent', c.loc["previous", "poutcome_nonexistent"])
print('age x job_retired', c.loc["age", "job_retired"])
print('age x marital_married', c.loc["age", "marital_married"])
print('age x marital_single', c.loc["age", "marital_single"])
print('education_primary x education_secondary', c.loc["education_primary", "education_secondary"])
print('education_primary x education_tertiary', c.loc["education_primary", "education_tertiary"])
print('education_secondary x education_tertiary', c.loc["education_secondary", "education_tertiary"])
